# %% [markdown]
# ## Imports

# %%
try:
        
    import h5py
    
    from ipywidgets import widgets, Layout, interact, interactive, interactive_output, Dropdown
    from IPython.display import display
    import matplotlib.pyplot as mplt
    import scipy
    from sympy import symbols, Eq, solve
    import numpy as np
    import random
    import seaborn as sns 
    import pandas as pd
    import graphing as gr
    #!pip install viola
    ########## Modules required for artist drawing on matplotlib
    import matplotlib.path as mpath
    import matplotlib.lines as mlines
    import matplotlib.patches as mpatches
    from matplotlib.collections import PatchCollection
    
      
except ModuleNotFoundError:
        print("A class you are trying to import is not present in the directory")
    
except Exception:
        print("Something went wrong - modules have not been imported")

else: 
    print("All relevant classes imported")
# Out:
# All relevant classes imported

# %%
g_exc = [4,4.5,5,5.5,6,6.5]



peak_soma_v_arr_z1 = []
peak_soma_v_arr_z1.append("0")
peak_soma_v_arr_z1.append("0")
peak_soma_v_arr_z1.append("0")
peak_soma_v_arr_z1.append("0")
peak_soma_v_arr_z1.append("1")
peak_soma_v_arr_z1.append("1")


peak_soma_v_arr_gk1 = []
peak_soma_v_arr_gk1.append('0')
peak_soma_v_arr_gk1.append('0') 
peak_soma_v_arr_gk1.append('0') #gk5
peak_soma_v_arr_gk1.append('0')
peak_soma_v_arr_gk1.append('0') #gk6
peak_soma_v_arr_gk1.append('1')

peak_soma_v_arr_z3 = []
peak_soma_v_arr_z3.append("0")
peak_soma_v_arr_z3.append("0")
peak_soma_v_arr_z3.append("0")
peak_soma_v_arr_z3.append("0")
peak_soma_v_arr_z3.append("1")
peak_soma_v_arr_z3.append("1")


fig_b,ax_1 = mplt.subplots(1,1,figsize=(8,3))
sns.despine(offset=5)
ax_1.plot(g_exc,peak_soma_v_arr_z1,"*-", label ='C4: g_kcc2 = 20us/cm2; z = -0.85 ',color= '#555555')
ax_1.plot(g_exc,peak_soma_v_arr_z3,"*-", label ='C4: g_kcc2 = 20us/cm2; z = -1.05 ', color = '#C70007')
ax_1.plot(g_exc,peak_soma_v_arr_gk1,"*-", label = 'C4: g_kcc2 = 80us/cm2; z = -0.85 ',color='#8800C7')





ax_1.set_yticklabels(["No AP", "AP"])
ax_1.set_xlabel("g_NMDA (nS)", fontsize=16)
ax_1.tick_params(axis='y', which='major', labelsize=18)
ax_1.tick_params(axis='x', which='major', labelsize=14)
ax_1.legend(fontsize =14, loc='upper left',frameon=False)
# Out:
# C:\Users\Eran\AppData\Local\Temp/ipykernel_8936/3592271096.py:41: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax_1.set_yticklabels(["No AP", "AP"])
